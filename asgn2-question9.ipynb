# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(0, 1, 1000)

# %%
plt.figure()
plt.hist(x, bins=100, density=True, edgecolor='black')
plt.xlabel("Random Number Value")
plt.ylabel("Frequency")
plt.title("Uniformly Distributed Random Numbers")
# Out:
# Text(0.5, 1.0, 'Uniformly Distributed Random Numbers')

# %%
plt.savefig('histogram_plot.pdf')
